# %%
#Faça um Programa que peça 2 números inteiros e um número real. Calcule e mostre:
#o produto do dobro do primeiro com metade do segundo .
#a soma do triplo do primeiro com o terceiro.
#o terceiro elevado ao cubo.
n_1 = int(input('digite o primeiro numero inteiro'))
n_2 = int(input('digite o segundo numero inteiro'))
n_3 = float(input('digite o terceiro numero real'))
pdpms = (n_1 * 2) * (n_2/2)
soma_t12 = (3*n_1) + (n_3)
terc_3 = (n_3) ** 3
print('o produto do dobro do primeiro com metade do segundo é:',pdpms)
print('a soma do triplo do primeiro com o terceiro.',soma_t12)
print('o terceiro elevado ao cubo.',terc_3)
# Out:
# digite o primeiro numero inteiro1
# digite o segundo numero inteiro2
# digite o terceiro numero real3
# o produto do dobro do primeiro com metade do segundo é: 2.0
# a soma do triplo do primeiro com o terceiro. 6.0
# o terceiro elevado ao cubo. 27.0
