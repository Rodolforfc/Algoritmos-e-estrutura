# %%
#Faça um programa que peça o tamanho de um arquivo para download (em MB)
# e a velocidade de um link de Internet (em Mbps), calcule e informe o tempo
# aproximado de download do arquivo usando este link (em minutos).

tam_arq = float(input('informe o tamanho do arquivo'))
velocida = float(input('informe a velocidade do link'))
tempo_down = tam_arq/(velocida/8)
print(' O tempo do download é:',tempo_down )
# Out:
# informe o tamanho do arquivo10
# informe a velocidade do link2
#  O tempo do download é: 40.0
