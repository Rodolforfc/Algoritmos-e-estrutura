# %%
# Aluno: Rodolfo Rivelino
#Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
# C = 5 * ((F-32) / 9).
temperatura_f = float (input('Digite uma temperatura em graus Fahrenheit:'))
c = 5 * ((temperatura_f -32)/9)
print("O valor da temperatura em graus Celsius",c)
# Out:
# Digite uma temperatura em graus Fahrenheit:100
# O valor da temperatura em graus Celsius 37.77777777777778
