# %%
# Faça um programa para uma loja de tintas. 
#O programa deverá pedir o tamanho em metros quadrados da área a ser pintada.
# Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados
# e que a tinta é vendida em latas de 18 litros, que custam R$ 80,00. Informe 
# ao usuário a quantidades de
#latas de tinta a serem compradas e o preço total.
area_pintada = float(input('Digite o valor em metros quadrados da área a ser pintada:'))
quant_latas_comp = area_pintada / 54
valor_total = quant_latas_comp *80
print(' A quantidade de latas a ser comprada é:',quant_latas_comp, 'e o valor a pagar será:', valor_total)
# Out:
# Digite o valor em metros quadrados da área a ser pintada:100
#  A quantidade de latas a ser comprada é: 1.8518518518518519 e o valor a pagar será: 148.14814814814815
