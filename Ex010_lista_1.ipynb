# %%
# Aluno: Rodolfo Rivelino 
# Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
C = float(input('digite o valor da temperatura em graus Celsis:'))
F = (1.8 * C + 32)
print('O valor da temperatura em graus Fahrenheit é: ', F)
# Out:
# digite o valor da temperatura em graus Celsis:100
# O valor da temperatura em graus Fahrenheit é:  212.0
